# %% [markdown]
# # SandBox Python Notebook
# This is is a python notebook where one can interactively test code snips. Once a piece of code works fine, it can be pasted into the actual codebase.
#
# This notebook can also be used as testing new stuff. It is going to be very important to keep this file clean.
#
# One benefit of this file is that you don't need to toggle between a CLI and codebase which is important when you are just starting out

# %%
## Dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from alpha_vantage.timeseries import TimeSeries

# %%
ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='TSLA',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
data['4. close']
# Out:
# date
# 2023-05-12 20:00:00    167.20
# 2023-05-12 19:59:00    167.25
# 2023-05-12 19:58:00    167.26
# 2023-05-12 19:57:00    167.30
# 2023-05-12 19:56:00    167.29
#                         ...
# 2023-05-01 04:06:00    163.70
# 2023-05-01 04:05:00    164.15
# 2023-05-01 04:04:00    164.28
# 2023-05-01 04:02:00    164.60
# 2023-05-01 04:01:00    164.58
# Name: 4. close, Length: 8869, dtype: float64

# %%
ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='^GSPC',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10612\1498148174.py in <module>
#       1 ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
# ----> 2 data, meta_data = ts.get_intraday(symbol='^GSPC',interval='1min', outputsize='full')
#       3 data['4. close'].plot()
#       4 plt.title('Intraday Times Series for the MSFT stock (1 min)')
#       5 plt.show()
#
# c:\Users\JaldhirTrivedi\anaconda3\envs\myenv\lib\site-packages\alpha_vantage\alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# ...
